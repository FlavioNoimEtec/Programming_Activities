# %%
aula = "hello world"

# %%
print (aula)
# Out:
# hello world

# %%
aula

# %%
#Entrada
lado = 4

# %%
#processamento
area = lado * lado

# %%
#saida
print("A área do quadrado é",area)
# Out:
# A área do quadrado é 16

# %%
#teste

comida = int(input("Strogonoff de Carne ou Frango?"))

if comida : "frango"
print("frango")

else :
